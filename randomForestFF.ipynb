# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
# %matplotlib inline
import matplotlib.pyplot as plt

features = pd.read_csv('AF_ML_Training.csv')
# features.head(5)

features = pd.get_dummies(features)
features.head(5)

labels = np.array(features['Quantity'])
features = features.drop('Quantity', axis=1)
feature_list = list(features.columns)
features = np.array(features)
# features
# train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.25, random_state=42)

test = pd.read_csv('testF.csv')
testTemp = pd.read_csv('testF.csv')
# print(testTemp)

testArr = np.array(testTemp)
# print(testArr)
# print(testArr.shape)

test = pd.get_dummies(test)
test_labels = np.array(test['Quantity'])
test = test.drop('Quantity', axis=1)
test_list = list(test.columns)
# print(test_list)
test = np.array(test)

# people = np
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
# %matplotlib inline

features = pd.read_csv('AF_ML_Training.csv')
# features.head(5)

features = pd.get_dummies(features)
features.head(5)

labels = np.array(features['Quantity'])
features = features.drop('Quantity', axis=1)
feature_list = list(features.columns)
features = np.array(features)
print("features: ", features)
# features
# train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.25, random_state=42)

test = pd.read_csv('testF.csv')
testTemp = pd.read_csv('testF.csv')
# print(testTemp)

testArr = np.array(testTemp)
# print(testArr)
# print(testArr.shape)

test = pd.get_dummies(test)
test_labels = np.array(test['Quantity'])
test = test.drop('Quantity', axis=1)
test_list = list(test.columns)
# print(test_list)
test = np.array(test)

# people = np.unique()

finalArr = np.array(testArr)

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(features, labels)

predictions = rf.predict(test)
predictions
final = np.array(predictions)

humanResource = []
for i in range(len(testArr)):
    for j in range(len(testArr[i])):
        if testArr[i][j] is 'L':
            finalArr[i][j+1] = final[i]
            humanResource.append(i)

for data in finalArr:
    data[8] = data[7] * data[6] * 1000

ffinal = []

for i in humanResource:
    ffinal.append(finalArr[i])

people = ['R2039', 'R2040', 'R2041', 'R2042', 'R2043']

finalArr = np.array(testArr)

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(features, labels)

predictions = rf.predict(test)
predictions
final = np.array(predictions)

humanResource = []
for i in range(len(testArr)):
    for j in range(len(testArr[i])):
        if testArr[i][j] is 'L':
            finalArr[i][j+1] = final[i]
            humanResource.append(i)

for data in finalArr:
    data[8] = data[7] * data[6] * 1000

ffinal = []

for i in humanResource:
    ffinal.append(finalArr[i])

print(final)

q1 = []
q2 = []
q3 = []
q4 = []
q5 = []

c1 = []
c2 = []
c3 = []
c4 = []
c5 = []


for f in ffinal:
    if f[4] == 'R2039':
        q1.append(f[1])
        c1.append(f[8])

    if f[4] == 'R2040':
        q2.append(f[1])
        c2.append(f[8])

    if f[4] == 'R2041':
        q3.append(f[1])
        c3.append(f[8])

    if f[4] == 'R2042':
        q4.append(f[1])
        c4.append(f[8])

    if f[4] == 'R2043':
        q5.append(f[1])
        c5.append(f[8])


plt.plot(q1, c1, label='R2039', lw=2, marker='.', color='b')
plt.plot(q2, c2, label='R2040', lw=2, marker='.', color='g')
plt.plot(q3, c3, label='R2041', lw=2, marker='.', color='r')
plt.plot(q4, c4, label='R2042', lw=2, marker='.', color='c')
plt.plot(q5, c5, label='R2043', lw=2, marker='.', color='m')

plt.xlabel('Quantity')
plt.ylabel('Cost')
plt.grid()
plt.legend(loc='upper right')
# plt.show()
plt.savefig('final.png')
# Out:
# ('features: ', array([[600,  20,   1, ...,   0,   0,   1],
#        [600,   8,  23, ...,   0,   0,   1],
#        [600,   9,   4, ...,   0,   0,   1],
#        ...,
#        [492, 900,   3, ...,   1,   0,   0],
#        [492, 100, 400, ...,   1,   0,   0],
#        [492,   1,   2, ...,   1,   0,   0]]))
# [ 90.     2.   483.   231.    64.     4.77   4.86   4.97   3.21   4.03
#    4.01   4.01   2.    90.     2.   483.   231.    64.     4.77   4.86
#    4.97   3.21   4.03   4.01   4.01   2.    90.     2.   483.   231.
#   64.     4.77   4.86   4.97   3.21   4.03   4.01   4.01   2.    90.
#    2.   483.   231.    64.     4.77   4.86   4.97   3.21   4.03   4.01
#    4.01   2.    90.     2.   483.   231.    64.     4.74   4.93   4.91
#    3.27   4.02   4.     4.     2.    90.     2.   483.   231.    64.
#    4.8    4.98   4.91   3.89   4.02   4.     4.     2.    90.     2.
#  483.   231.    64.     4.79   4.97   4.9    3.89   4.01   4.     4.
# ...
